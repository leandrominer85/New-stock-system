# %%
#Importing modules
import pandas as pd

# %%
#reading the estoque dataframe
df = pd.read_csv('../data/etl/estoque.csv',index_col=0 )

# %%
#Getting repeated keys
keys = df.groupby(['key']).supplier.nunique()
keys = keys[keys>1].keys()

# %%
# Copy of dataframe with the repeated keys
df2=df[df['key'].isin(keys)].sort_values(by = 'key')

# %%
# Creating a dataframe with the mim price and quantities
min_df = df2.groupby(['key', 'supplier'])['Price','Quantity'].min().unstack()
# Out:
# C:\Users\eppmi\AppData\Local\Temp/ipykernel_1740/2508169433.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   min_df = df2.groupby(['key', 'supplier'])['Price','Quantity'].min().unstack()

# %%
print(min_df.head())
# Out:
#            Price                                                   Quantity  \
# supplier carbwel ima jahu lucios medauto metal real rufato sueyasu  carbwel
# key
# 0            NaN NaN  NaN    NaN     NaN   0.0  NaN   7.92     NaN      NaN
# 3rho310      0.0 NaN  NaN  36.05     NaN   NaN  NaN    NaN     0.0      2.0
# 3rho318      NaN NaN  NaN  58.48     NaN   NaN  NaN    NaN     0.0      NaN
# 3rho319      0.0 NaN  NaN  41.90     NaN   NaN  NaN    NaN     0.0      2.0
# 3rho322      0.0 NaN  NaN    NaN     NaN   NaN  NaN    NaN     0.0      1.0
#
#
# supplier ima jahu lucios medauto metal real rufato sueyasu
# key
# 0        NaN  NaN    NaN     NaN   1.0  NaN    1.0     NaN
# 3rho310  NaN  NaN   56.0     NaN   NaN  NaN    NaN    28.0
# 3rho318  NaN  NaN    7.0     NaN   NaN  NaN    NaN     2.0
# 3rho319  NaN  NaN    8.0     NaN   NaN  NaN    NaN     6.0
# 3rho322  NaN  NaN    NaN     NaN   NaN  NaN    NaN     1.0

# %%
#Creating a dataframe to get only the prices
df_price_min = df2.groupby(by=['key', 'supplier'])['Price'].min().unstack()

# %%
# Get a array with the minimun price for each row
price_min = df_price_min.min(axis=1).values

# %%
# Start with a empty list for the quantities and other for temporary use
min_q=[]
temp = []

#Iterate through the range of the min DF
for row in range(len(min_df)):
    #Iterate through each key tuple
    for k in min_df.keys():
        # If the key is 'Price' and the correponding row and price column are equal to the minimum from the price array
        # then append the corresponding supplier row to the temp list 
        if k[0] == 'Price' and min_df['Price'][k[1]][row] == price_min[row]:
            temp.append(min_df['Quantity'][k[1]][row])
    # If there is any value in the temp list get the sum and append to the min_q list, then reset the list
    if len(temp) > 0:
            min_q.append(sum(temp))
            temp=[]
    else:
        temp=[]

# %%
# Add the col to the dataframe
min_df['min_qt'] = min_q

# %%
min_df
# Out:
#            Price                                                   Quantity  \
# supplier carbwel ima jahu lucios medauto metal real rufato sueyasu  carbwel
# key
# 0            NaN NaN  NaN    NaN     NaN   0.0  NaN   7.92     NaN      NaN
# 3rho310      0.0 NaN  NaN  36.05     NaN   NaN  NaN    NaN     0.0      2.0
# 3rho318      NaN NaN  NaN  58.48     NaN   NaN  NaN    NaN     0.0      NaN
# 3rho319      0.0 NaN  NaN  41.90     NaN   NaN  NaN    NaN     0.0      2.0
# 3rho322      0.0 NaN  NaN    NaN     NaN   NaN  NaN    NaN     0.0      1.0
# ...          ...  ..  ...    ...     ...   ...  ...    ...     ...      ...
# zen13158     0.0 NaN  NaN    NaN     NaN   NaN  NaN    NaN     0.0      2.0
# zen13283     0.0 NaN  NaN    NaN     NaN   NaN  NaN    NaN     0.0      2.0
# zen13284     0.0 NaN  NaN    NaN     NaN   NaN  NaN    NaN     0.0      1.0
# zen13286     0.0 NaN  NaN    NaN     NaN   NaN  NaN    NaN     0.0      1.0
# zen15000     0.0 NaN  NaN    NaN     NaN   NaN  NaN    NaN     0.0      5.0
#
#                                                            min_qt
# supplier ima jahu lucios medauto metal real rufato sueyasu
# key
# 0        NaN  NaN    NaN     NaN   1.0  NaN    1.0     NaN    1.0
# 3rho310  NaN  NaN   56.0     NaN   NaN  NaN    NaN    28.0   30.0
# 3rho318  NaN  NaN    7.0     NaN   NaN  NaN    NaN     2.0    2.0
# 3rho319  NaN  NaN    8.0     NaN   NaN  NaN    NaN     6.0    8.0
# 3rho322  NaN  NaN    NaN     NaN   NaN  NaN    NaN     1.0    2.0
# ...       ..  ...    ...     ...   ...  ...    ...     ...    ...
# zen13158 NaN  NaN    NaN     NaN   NaN  NaN    NaN     2.0    4.0
# zen13283 NaN  NaN    NaN     NaN   NaN  NaN    NaN     2.0    4.0
# zen13284 NaN  NaN    NaN     NaN   NaN  NaN    NaN     2.0    3.0
# zen13286 NaN  NaN    NaN     NaN   NaN  NaN    NaN     2.0    3.0
# zen15000 NaN  NaN    NaN     NaN   NaN  NaN    NaN     1.0    6.0
#
# [4686 rows x 19 columns]

# %%
min_df.to_csv('../data/etl/fourth_etl.csv')

# %%
#Save with timestamp
min_df.to_csv('../data/text_output/fourth_etl{}.txt'.format(pd.datetime.now().strftime("%Y-%m-%d %H-%M-%S")))
# Out:
# C:\Users\eppmi\AppData\Local\Temp/ipykernel_1740/3169794828.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   min_df.to_csv('../data/text_output/fourth_etl{}.txt'.format(pd.datetime.now().strftime("%Y-%m-%d %H-%M-%S")))
